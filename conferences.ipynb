# %%
import pandas as pd

# %%
conferences_df = pd.read_csv(r"/home/user/cfp_ranking_system/conferences.csv")
conferences_df["avgRecord_conf"] = conferences_df["avgRecord_conf"].apply(eval)

# %%
conferences_df
# Out:
#                  conf  totalCredits_conf  avgCredPerGame_conf  avgRank_conf  \
# 0    FBS Independents          35.796669             1.748450     22.500000
# 1                 SEC         110.802158             0.682664     46.875000
# 2             Big Ten          72.392365             0.396248     57.666667
# 3              Big 12          42.190032             0.252981     58.000000
# 4                 ACC         -14.617548            -0.078422     65.882353
# 5   American Athletic         -27.711132            -0.204460     67.785714
# 6       Mountain West         -44.622476            -0.371854     74.750000
# 7            Sun Belt         -83.682371            -0.597731     80.714286
# 8      Conference USA         -99.311152            -0.827593     86.666667
# 9              Pac-12         -25.325123            -1.143464     94.000000
# 10       Mid-American        -148.284700            -1.120076     94.692308
#
#     avgMargin_conf avgRecord_conf
# ...
