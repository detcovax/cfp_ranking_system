# %%
import pandas as pd

# %%
conferences_df = pd.read_csv(r"/home/user/cfp_ranking_system/conferences.csv")
conferences_df["avgRecord_conf"] = conferences_df["avgRecord_conf"].apply(eval)

# %%
conferences_df
# Out:
#                  conf  totalCredits_conf  avgCredPerGame_conf  avgRank_conf  \
# 0    FBS Independents          54.820802             2.284200     23.000000
# 1                 SEC         206.157566             1.073737     45.937500
# 2             Big Ten         189.589336             0.877728     53.777778
# 3              Big 12         148.325531             0.772529     54.187500
# 4                 ACC          92.337130             0.452633     60.058824
# 5   American Athletic         -24.888210            -0.140409     74.928571
# 6       Mountain West         -40.662338            -0.282377     79.250000
# 7            Sun Belt         -81.731910            -0.486499     84.357143
# 8      Conference USA        -105.908955            -0.735479     90.333333
# 9        Mid-American        -141.228838            -0.905313     94.153846
# 10             Pac-12         -23.683973            -0.986832     95.000000
#
#     avgMargin_conf avgRecord_conf
# 0       190.000000     [9.5, 2.5]
# 1        57.875000     [7.5, 4.5]
# 2        39.777778   [6.94, 5.06]
# 3        19.937500   [6.88, 5.12]
# 4         1.000000   [6.47, 5.53]
# 5       -10.357143   [6.43, 5.43]
# 6       -12.250000   [6.17, 5.83]
# 7       -41.142857   [5.93, 6.07]
# 8       -47.250000   [5.58, 6.42]
# 9       -59.230769   [5.23, 6.77]
# 10      -76.500000     [4.0, 8.0]
