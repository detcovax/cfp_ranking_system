# %%
import pandas as pd

# %%
conferences_df = pd.read_csv(r"/home/user/cfp_ranking_system/conferences.csv")
conferences_df["avgRecord_conf"] = conferences_df["avgRecord_conf"].apply(eval)

# %%
conferences_df
# Out:
#                  conf  totalCredits_conf  avgCredPerGame_conf  avgRank_conf  \
# 0          Notre Dame          42.944254             3.578688      5.000000
# 1                 SEC         234.831632             1.062809     47.312500
# 2             Big Ten         242.702121             0.963734     53.555556
# 3              Big 12         186.739057             0.859378     53.812500
# 4               UConn           8.969815             0.689986     55.000000
# 5                 ACC         125.276236             0.518599     59.705882
# 6   American Athletic          -1.091549            -0.075095     73.928571
# 7       Mountain West         -30.449033            -0.264348     79.000000
# 8            Sun Belt         -74.700912            -0.465313     85.285714
# 9      Conference USA         -98.649579            -0.704216     90.666667
# 10             Pac-12         -19.448122            -0.835606     92.500000
# 11       Mid-American        -130.824220            -0.864435     93.000000
#
#     avgMargin_conf avgRecord_conf
# 0       293.000000    [10.0, 2.0]
# 1        56.937500   [7.81, 5.06]
# 2        45.611111    [7.5, 5.33]
# 3        20.312500   [7.19, 5.31]
# 4        62.000000     [9.0, 4.0]
# 5         2.705882   [6.88, 5.82]
# 6       -10.500000   [6.86, 5.86]
# 7       -15.083333   [6.42, 6.33]
# 8       -42.928571   [6.29, 6.57]
# 9       -51.166667    [6.0, 6.75]
# 10      -70.000000     [4.5, 8.0]
# 11      -59.615385   [5.46, 7.08]
